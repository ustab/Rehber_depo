# %% [markdown]
# <a href="https://colab.research.google.com/github/ustab/Rehber_depo/blob/main/Get_Dummy_OHE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/tested.csv')

# %%
data=pd.read_csv('/content/tested.csv', usecols=['Sex'])
data.head(5)
# Out:
#       Sex
# 0    male
# 1  female
# 2    male
# 3    male
# 4  female

# %%
pd.get_dummies(data).head()
# Out:
#    Sex_female  Sex_male
# 0           0         1
# 1           1         0
# 2           0         1
# 3           0         1
# 4           1         0
#    Sex_female  Sex_male
# 0           0         1
# 1           1         0
# 2           0         1
# 3           0         1
# 4           1         0

# %%
df=pd.concat([df, pd.get_dummies(data)], axis=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Sex_female',
#        'Sex_male'],
#       dtype='object')

# %%
df.drop(['Sex','Sex_male'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Sex_female'],
#       dtype='object')

# %%
df.rename(columns={'Sex_female':'Sex'}, inplace=True)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Sex'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass                              Name   Age  \
# 0          892         0       3                  Kelly, Mr. James  34.5
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  47.0
#
#    SibSp  Parch  Ticket    Fare Cabin Embarked  Sex
# 0      0      0  330911  7.8292   NaN        Q    0
# 1      1      0  363272  7.0000   NaN        S    1

# %%
data_E=pd.read_csv('/content/tested.csv', usecols=['Embarked'])

# %%
data_E=df.Embarked.unique()
data_E
# Out:
# array(['Q', 'S', 'C'], dtype=object)

# %%
pd.get_dummies(data_E)
# Out:
#    C  Q  S
# 0  0  1  0
# 1  0  0  1
# 2  1  0  0

# %%
df=pd.concat([df, pd.get_dummies(data_E)], axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0      1      0
# 2                       Myles, Mr. Thomas Francis  62.0      0      0
# 3                                Wirz, Mr. Albert  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0      1      1
# ..                                            ...   ...    ...    ...
# ...

# %%
df.drop(['Embarked'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name   Age  SibSp  Parch   Ticket  \
# 0                              Kelly, Mr. James  34.5      0      0   330911
# 1              Wilkes, Mrs. James (Ellen Needs)  47.0      1      0   363272
# 2                     Myles, Mr. Thomas Francis  62.0      0      0   240276
# 3                              Wirz, Mr. Albert  27.0      0      0   315154
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0      1      1  3101298
#
#       Fare Cabin  Sex    C    Q    S
# 0   7.8292   NaN    0  0.0  1.0  0.0
# 1   7.0000   NaN    1  0.0  0.0  1.0
# 2   9.6875   NaN    0  1.0  0.0  0.0
# 3   8.6625   NaN    0  NaN  NaN  NaN
# 4  12.2875   NaN    1  NaN  NaN  NaN

# %%
df.shape
# Out:
# (418, 14)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Sex              0
# C              415
# Q              415
# S              415
# dtype: int64

# %%
df.drop(['Age','Cabin','C','S','Q'], axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Sex            0
# dtype: int64

# %%
pip install skimpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.1 MB 9.5 MB/s
# ...
#      |████████████████████████████████| 214 kB 51.2 MB/s
# ...
#      |████████████████████████████████| 51 kB 6.7 MB/s
# ...
#   Attempting uninstall: Pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 2.7.1
#     Uninstalling typeguard-2.7.1:
#       Successfully uninstalled typeguard-2.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# ...

# %%
from skimpy import clean_columns
df = clean_columns(df)

# %%
df
# Out:
#      passenger_id  survived  pclass  \
# 0             892         0       3
# 1             893         1       3
# 2             894         0       2
# 3             895         0       3
# 4             896         1       3
# ..            ...       ...     ...
# 413          1305         0       3
# 414          1306         1       1
# 415          1307         0       3
# 416          1308         0       3
# 417          1309         0       3
#
#                                              name  sib_sp  parch  \
# 0                                Kelly, Mr. James       0      0
# 1                Wilkes, Mrs. James (Ellen Needs)       1      0
# 2                       Myles, Mr. Thomas Francis       0      0
# 3                                Wirz, Mr. Albert       0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)       1      1
# ..                                            ...     ...    ...
# 413                            Spector, Mr. Woolf       0      0
# ...
